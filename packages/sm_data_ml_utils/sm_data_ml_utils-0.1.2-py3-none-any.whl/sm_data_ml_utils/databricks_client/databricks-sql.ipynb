# %%
import os
from databricks import sql
import pandas as pd

os.environ["DATABRICKS_HOST"] = "hipages-ml-prod-ws.cloud.databricks.com"
os.environ["DATABRICKS_SQL_PATH"] = "sql/1.0/warehouses/259c975f50595ca8"
os.environ["DATABRICKS_TOKEN"] = "dapid2e469459f85da3a8b66f929d4db56ad"

# %%
connection = sql.connect(
    server_hostname="hipages-ml-prod-ws.cloud.databricks.com",
    http_path="sql/1.0/warehouses/259c975f50595ca8",
    access_token="dapid2e469459f85da3a8b66f929d4db56ad",
)

# %%
cursor = connection.cursor()

# %%
cursor.execute('SELECT * FROM long_lake.dim_category_databricks limit 10')
result = cursor.fetchall()

# %%
df = pd.DataFrame(result, columns=[col[0] for col in cursor.description])

# %%
# Out:
#    category_dim_key effective_start_date effective_end_date effective_now  \
# 0                 0  2016-08-18 23:22:00                                t
# 1                 1  2016-08-18 23:22:00                                t
# 2                 2  2016-08-18 23:22:00                                t
# 3                 3  2016-08-18 23:22:00                                t
# 4                 4  2016-08-18 23:22:00                                t
# 5                 5  2016-08-18 23:22:00                                t
# 6                 6  2016-08-18 23:22:00                                t
# 7                 7  2016-08-18 23:22:00                                t
# 8                 8  2016-08-18 23:22:00                                t
# 9                 9  2016-08-18 23:22:00                                t
#
#   effective_change_date effective_change_reason application_code  \
# 0                                                            HIP
# ...

# %%
type(connection)
# Out:
# databricks.sql.client.Connection

# %%
import databricks

# %%
df = cursor.execute('SELECT * FROM long_lake.dim_category_databricks limit 10')

# %%
df.dtypes
# Out:
# category_dim_key                int64
# effective_start_date           object
# effective_end_date             object
# effective_now                  object
# effective_change_date          object
# effective_change_reason        object
# application_code               object
# category_key                   object
# category_seo_key               object
# category_id                     int64
# parent_category_id              int64
# parent_category                object
# category_group                 object
# test_indicator                 object
# public_indicator               object
# person_singular                object
# person_plural                  object
# category_grouping              object
# grandparent_category           object
# category_grouping_emergency    object
# category                       object
# category_taxonomy              object
# master_category                object
# dtype: object

# %%
from client import DatabricksSQLClient

# %%
databricks_client = DatabricksSQLClient(
    # host="hipages-ml-prod-ws.cloud.databricks.com",
    # sql_path="sql/1.0/warehouses/259c975f50595ca8",
    # token="dapid2e469459f85da3a8b66f929d4db56ad",
)

# %%
databricks_client.query_as_pandas("select * from long_lake.dim_category_databricks limit 10")
# Out:
#    category_dim_key effective_start_date effective_end_date effective_now  \
# 0                 0  2016-08-18 23:22:00                                t
# 1                 1  2016-08-18 23:22:00                                t
# 2                 2  2016-08-18 23:22:00                                t
# 3                 3  2016-08-18 23:22:00                                t
# 4                 4  2016-08-18 23:22:00                                t
# 5                 5  2016-08-18 23:22:00                                t
# 6                 6  2016-08-18 23:22:00                                t
# 7                 7  2016-08-18 23:22:00                                t
# 8                 8  2016-08-18 23:22:00                                t
# 9                 9  2016-08-18 23:22:00                                t
#
#   effective_change_date effective_change_reason application_code  \
# 0                                                            HIP
# ...
